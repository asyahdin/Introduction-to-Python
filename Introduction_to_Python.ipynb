# %% [markdown]
# <a href="https://colab.research.google.com/github/asyahdin/Introduction-to-Python/blob/main/Introduction_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# ### Data Science

# %% [markdown]
# **Big Data**

# %% [markdown]
# *Python*

# %% [markdown]
# [please visit my linkedin profile](https://www.linkedin.com/in/nur-aishah-mohd-din)

# %% [markdown]
# ![Iconbee sijil_page-0001.jpg](data:image/jpeg;base64,...)
# ```
# # This is formatted as code
# ```

# %% [markdown]
# 1.   Data Science
# 2.   Python
# 3.   Big Data

# %% [markdown]
# *   Data Science
#
# *   Python
#
# *   Big Data
#
# *Big Data*
#
# *Data Science*

# %% [markdown]
# a = 10
# b = 20

# %%
a = 10
b= 20

c = a*b

print (c)
# Out:
# 200

# %%
c = a+b
print (c)
# Out:
# 30

# %%
c = a/b
print (c)
# Out:
# 0.5

# %%
import pandas as pd

df = pd.read_csv('NFLX.csv')

df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
df.head ()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
df.tail (10)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 997   2019-12-03  302.220001  307.359985  301.880005  306.160004  306.160004
# 998   2019-12-04  308.429993  308.429993  303.269989  304.320007  304.320007
# 999   2019-12-05  305.269989  306.480011  298.809998  302.859985  302.859985
# 1000  2019-12-06  304.700012  307.850006  302.600006  307.350006  307.350006
# 1001  2019-12-09  307.350006  311.489990  302.440002  302.500000  302.500000
# 1002  2019-12-10  296.119995  298.940002  292.019989  293.119995  293.119995
# 1003  2019-12-11  294.489990  299.429993  294.200012  298.929993  298.929993
# 1004  2019-12-12  295.670013  299.170013  295.059998  298.440002  298.440002
# 1005  2019-12-13  298.500000  301.799988  297.250000  298.500000  298.500000
# 1006  2019-12-16  300.850006  305.709991  298.630005  304.209991  304.209991
#
#         Volume
# 997    4992800
# 998    3512100
# 999    4615500
# 1000   4457800
# 1001   5748400
# 1002  10476100
# ...

# %%
df.shape
# Out:
# (1007, 7)

# %% [markdown]
# **Python Data Types**
#
#
#
# *   String
# *   Integer
# *   Float

# %%
'Data Science'
8.8
2024
# Out:
# 2024

# %%
type('Data Science')
# Out:
# str

# %%
type(8.8)
# Out:
# float

# %%
type(2024)
# Out:
# int

# %% [markdown]
# **Int,float, complex**

# %%
#complex
A = 3 + 5*b

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
type('2024')
# Out:
# str

# %%
type('?#16.8')
# Out:
# str

# %%
type('data')
# Out:
# str

# %% [markdown]
# **Boolean Data Types**
#
# *   True
# *   False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# *Expressions, Variables, Conditions*
#
# <ul>
#     <li>subtraction: <b>-</b></li>
#     <li>addition: <b>+</b></li>
#     <li>division: <b>/</b></li>
#     <li>floor division <b>//</b></li>
#     <li>multiplication: <b>*</b></li>
#     <li>modulus: <b>%</b></li>
#     <li>exponent: <b>**</b></li>

# %% [markdown]
# **Expressions**

# %%
x = 8
z = 2

y = x / z

y
# Out:
# 4.0

# %%
type(y)
# Out:
# float

# %%
y = x // z

# %%
y
# Out:
# 4

# %%
type(y)
# Out:
# int

# %%
d = 8
e = 3

f = d / e

f
# Out:
# 2.6666666666666665

# %%
f = d // e

# %%
f
# Out:
# 2

# %%
b1 = 10%3
b2 = 10%2
b3 = 11%2
b4 = 11%3

print(b1)
print(b2)
print(b3)
print(b4)
# Out:
# 1
# 0
# 1
# 2

# %%
2**3
# Out:
# 8

# %%
8**4
# Out:
# 4096

# %% [markdown]
# Variables

# %%
type = 'big data'

# %%
type(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-5b1f786095c8> in <cell line: 1>()
# ----> 1 type(20)
#
# TypeError: 'str' object is not callable

# %%
type
# Out:
# 'big data'

# %%
1234 = 'Data Science'
# Out:
#   File "<ipython-input-30-ce9d1198aae1>", line 1
#     1234 = 'Data Science'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
machine learning = 'Data Science'
# Out:
#   File "<ipython-input-31-90a1c9da181f>", line 1
#     machine learning = 'Data Science'
#             ^
# SyntaxError: invalid syntax

# %%
machine_learning = 'Data Science'

# %%
machine_learning
# Out:
# 'Data Science'

# %%
# %whos
# Out:
# Variable           Type    Data/Info
# ------------------------------------
# abc                int     2025
# b1                 int     1
# b2                 int     0
# b3                 int     1
# b4                 int     2
# d                  int     8
# e                  int     3
# f                  int     2
# machine_learning   str     Data Science
# type               str     big data
# x                  int     8
# y                  int     4
# z                  int     2

# %%
abc = 2025

# %% [markdown]
# Conditions
#
# <ul>
#     <li>equal: <b>==</b></li>
#     <li>not equal: <b>!=</b></li>
#     <li>greater than: <b>></b></li>
#     <li>less than: <b>&lt;</b></li>
#     <li>greater than or equal to: <b>>=</b></li>
#     <li>less than or equal to: <b>&lt;=</b></li>
# </ul>

# %%
year = 2024

year == 2024
# Out:
# True

# %%
year != 2025
# Out:
# True

# %%
year == 2026
# Out:
# False

# %% [markdown]
# ***String Indexing***

# %%
singer = 'Micheal Jackson'

singer
# Out:
# 'Micheal Jackson'

# %%
type (singer)
# Out:
# str

# %%
print (singer)
print (singer[2])
print (singer[5])
print (singer[10])
print (singer[13])
# Out:
# Micheal Jackson
# c
# a
# c
# o
