# %% [markdown]
# <a href="https://colab.research.google.com/github/asyahdin/Introduction-to-Python/blob/main/Exercises_DataWrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

mydata = pd.read_csv('NHANES.csv')
mydata.head(10)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
# 5  83737     2.0     2.0     NaN       2         2        72         1
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
# 8  83743     NaN     NaN     NaN       2         1        18         5
# 9  83744     1.0     NaN     NaN       2         1        56         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# ...

# %%
mydata.shape
# Out:
# (5735, 28)

# %%
mydata.columns #columns name

# %%
mydata.info() #a data from dataset #want to know which is missing value in column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      5735 non-null   int64
#  1   ALQ101    5208 non-null   float64
#  2   ALQ110    1731 non-null   float64
#  3   ALQ130    3379 non-null   float64
#  4   SMQ020    5735 non-null   int64
#  5   RIAGENDR  5735 non-null   int64
#  6   RIDAGEYR  5735 non-null   int64
#  7   RIDRETH1  5735 non-null   int64
#  8   DMDCITZN  5734 non-null   float64
#  9   DMDEDUC2  5474 non-null   float64
#  10  DMDMARTL  5474 non-null   float64
#  11  DMDHHSIZ  5735 non-null   int64
#  12  WTINT2YR  5735 non-null   float64
#  13  SDMVPSU   5735 non-null   int64
#  14  SDMVSTRA  5735 non-null   int64
#  15  INDFMPIR  5134 non-null   float64
#  16  BPXSY1    5401 non-null   float64
#  17  BPXDI1    5401 non-null   float64
#  18  BPXSY2    5535 non-null   float64
#  19  BPXDI2    5535 non-null   float64
# ...

# %%
mydata.describe(include='all') #describe all columns
# Out:
#                SEQN       ALQ101       ALQ110       ALQ130       SMQ020  \
# count   5735.000000  5208.000000  1731.000000  3379.000000  5735.000000
# mean   88678.583435     1.336406     1.587522     3.911512     1.607149
# std     2882.139237     0.505514     0.623940    34.341839     0.571975
# min    83732.000000     1.000000     1.000000     1.000000     1.000000
# 25%    86164.000000     1.000000     1.000000     1.000000     1.000000
# 50%    88668.000000     1.000000     2.000000     2.000000     2.000000
# 75%    91178.500000     2.000000     2.000000     3.000000     2.000000
# max    93702.000000     9.000000     9.000000   999.000000     9.000000
#
#           RIAGENDR     RIDAGEYR     RIDRETH1     DMDCITZN     DMDEDUC2  ...  \
# count  5735.000000  5735.000000  5735.000000  5734.000000  5474.000000  ...
# mean      1.518919    48.052310     3.042371     1.185385     3.441725  ...
# std       0.499686    18.431011     1.296793     0.491678     1.309700  ...
# ...

# %%
pd.set_option('display.max_columns', None)

mydata.head(10)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
# 5  83737     2.0     2.0     NaN       2         2        72         1
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
# 8  83743     NaN     NaN     NaN       2         1        18         5
# 9  83744     1.0     NaN     NaN       2         1        56         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# ...

# %%
mydata.isnull().sum() #want to know how manyy missing value each colunm
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %% [markdown]
# *Column with missing value**
#
#
# ALQ101   :    527
#
# ALQ110   :   4004
#
# ALQ130   :   2356
#
# DMDCITZN   :    1
#
# DMDEDUC2  :   261
#
# DMDMARTL  :   261
#
# INDFMPIR  :   601
#
# BPXSY1    :   334
#
# BPXDI1    :   334
#
# BPXSY2    :   200
#
# BPXDI2    :   200
#
# BMXWT    :     69
#
# BMXHT      :   62
#
# BMXBMI    :    73
#
# BMXLEG     :  390
#
# BMXARML   :   308
#
# BMXARMC   :   308
#
# BMXWAIST   :  367
#
# HIQ210   :   1003

# %%
mean_alq101 = mydata['ALQ101'].astype('float').mean() #convert to float
mean_alq101 #got the value of gender
# Out:
# 1.336405529953917

# %%
import numpy as np

mydata['ALQ101'].replace(np.nan, mean_alq101, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_alq110 = mydata['ALQ110'].astype('float').mean() #convert to float
mean_alq110
# Out:
# 1.5875216637781628

# %%
mydata['ALQ110'].replace(np.nan, mean_alq110, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_alq130 = mydata['ALQ130'].astype('float').mean() #convert to float
mean_alq130
# Out:
# 3.9115122817401597

# %%
mydata['ALQ130'].replace(np.nan, mean_alq130, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_dmdcitzn = mydata['DMDCITZN'].astype('float').mean()
mydata['DMDCITZN'].replace(np.nan, mean_dmdcitzn, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_dmdeduc2 = mydata['DMDEDUC2'].astype('float').mean()
mydata['DMDEDUC2'].replace(np.nan, mean_dmdeduc2, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_dmdmartl = mydata['DMDMARTL'].astype('float').mean()
mydata['DMDMARTL'].replace(np.nan, mean_dmdmartl, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL       0
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_indfmpir = mydata['INDFMPIR'].astype('float').mean()
mydata['INDFMPIR'].replace(np.nan, mean_indfmpir, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL       0
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR       0
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_bpxsy1 = mydata['BPXSY1'].astype('float').mean()
mydata['BPXSY1'].replace(np.nan, mean_bpxsy1, inplace=True)
mydata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL       0
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR       0
# BPXSY1         0
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_bpxdi1 = mydata['BPXDI1'].astype('float').mean()
mydata['BPXDI1'].replace(np.nan, mean_bpxdi1, inplace=True)

mean_bpxsy2 = mydata['BPXSY2'].astype('float').mean()
mydata['BPXSY2'].replace(np.nan, mean_bpxsy2, inplace=True)

mean_bpxdi2 = mydata['BPXDI2'].astype('float').mean()
mydata['BPXDI2'].replace(np.nan, mean_bpxdi2, inplace=True)

mean_bmxwt = mydata['BMXWT'].astype('float').mean()
mydata['BMXWT'].replace(np.nan, mean_bmxwt, inplace=True)

mean_bmxht = mydata['BMXHT'].astype('float').mean()
mydata['BMXHT'].replace(np.nan, mean_bmxht, inplace=True)

mean_bmxbmi = mydata['BMXBMI'].astype('float').mean()
mydata['BMXBMI'].replace(np.nan, mean_bmxbmi, inplace=True)

mean_bmxleg = mydata['BMXLEG'].astype('float').mean()
mydata['BMXLEG'].replace(np.nan, mean_bmxleg, inplace=True)

mean_bmxarml = mydata['BMXARML'].astype('float').mean()
mydata['BMXARML'].replace(np.nan, mean_bmxarml, inplace=True)

mean_bmxarmc = mydata['BMXARMC'].astype('float').mean()
mydata['BMXARMC'].replace(np.nan, mean_bmxarmc, inplace=True)

mean_bmxwaist = mydata['BMXWAIST'].astype('float').mean()
mydata['BMXWAIST'].replace(np.nan, mean_bmxwaist, inplace=True)

mean_hiq210 = mydata['HIQ210'].astype('float').mean()
mydata['HIQ210'].replace(np.nan, mean_, inplace=True)


mydata.isnull().sum()
# Out:
# SEQN        0
# ALQ101      0
# ALQ110      0
# ALQ130      0
# SMQ020      0
# RIAGENDR    0
# RIDAGEYR    0
# RIDRETH1    0
# DMDCITZN    0
# DMDEDUC2    0
# DMDMARTL    0
# DMDHHSIZ    0
# WTINT2YR    0
# SDMVPSU     0
# SDMVSTRA    0
# INDFMPIR    0
# BPXSY1      0
# BPXDI1      0
# BPXSY2      0
# BPXDI2      0
# BMXWT       0
# BMXHT       0
# BMXBMI      0
# BMXLEG      0
# BMXARML     0
# BMXARMC     0
# BMXWAIST    0
# HIQ210      0
# dtype: int64

# %% [markdown]
# **DATA FORMATING**

# %%
mydata.dtypes
# Out:
# SEQN          int64
# ALQ101      float64
# ALQ110      float64
# ALQ130      float64
# SMQ020        int64
# RIAGENDR      int64
# RIDAGEYR      int64
# RIDRETH1      int64
# DMDCITZN    float64
# DMDEDUC2    float64
# DMDMARTL    float64
# DMDHHSIZ      int64
# WTINT2YR    float64
# SDMVPSU       int64
# SDMVSTRA      int64
# INDFMPIR    float64
# BPXSY1      float64
# BPXDI1      float64
# BPXSY2      float64
# BPXDI2      float64
# BMXWT       float64
# BMXHT       float64
# BMXBMI      float64
# BMXLEG      float64
# BMXARML     float64
# BMXARMC     float64
# BMXWAIST    float64
# HIQ210      float64
# dtype: object

# %%
mydata.describe(include='all') #describe all columns
# Out:
#                SEQN       ALQ101       ALQ110       ALQ130       SMQ020  \
# count   5735.000000  5735.000000  5735.000000  5735.000000  5735.000000
# mean   88678.583435     1.336406     1.587522     3.911512     1.607149
# std     2882.139237     0.481723     0.342718    26.358733     0.571975
# min    83732.000000     1.000000     1.000000     1.000000     1.000000
# 25%    86164.000000     1.000000     1.587522     2.000000     1.000000
# 50%    88668.000000     1.000000     1.587522     3.911512     2.000000
# 75%    91178.500000     2.000000     1.587522     3.911512     2.000000
# max    93702.000000     9.000000     9.000000   999.000000     9.000000
#
#           RIAGENDR     RIDAGEYR     RIDRETH1     DMDCITZN     DMDEDUC2  \
# count  5735.000000  5735.000000  5735.000000  5735.000000  5735.000000
# mean      1.518919    48.052310     3.042371     1.185385     3.441725
# std       0.499686    18.431011     1.296793     0.491635     1.279545
# ...

# %% [markdown]
# **Data Normalization**
# (Min - Max)
#
# * ALQ130*
# * DMDMARTL
# * WTINT2YR*
# * SDMVSTRA
# * BPXSY1*
# * BPXDI1
# * BPXSY2
# * BPX

# %% [markdown]
# USING MIN AND MAX

# %%
mydata['ALQ130'] = (mydata['ALQ130'] - mydata['ALQ130'].min()) / (mydata['ALQ130'].max() - mydata['ALQ130'].min())

mydata[['ALQ130', 'WTINT2YR', 'BPXSY1']].head()
# Out:
#      ALQ130   WTINT2YR  BPXSY1
# 0  0.000000  134671.37   128.0
# 1  0.005010   24328.56   146.0
# 2  0.002917   12400.01   138.0
# 3  0.000000  102718.00   132.0
# 4  0.000000   17627.67   100.0

# %%
mydata['WTINT2YR'] = (mydata['WTINT2YR'] - mydata['WTINT2YR'].min()) / (mydata['WTINT2YR'].max() - mydata['WTINT2YR'].min())

mydata[['ALQ130', 'WTINT2YR', 'BPXSY1']].head()
# Out:
#      ALQ130  WTINT2YR  BPXSY1
# 0  0.000000  0.566227   128.0
# 1  0.005010  0.083168   146.0
# 2  0.002917  0.030947   138.0
# 3  0.000000  0.426342   132.0
# 4  0.000000  0.053833   100.0

# %%
mydata['BPXSY1'] = (mydata['BPXSY1'] - mydata['BPXSY1'].min()) / (mydata['BPXSY1'].max() - mydata['BPXSY1'].min())

mydata[['ALQ130', 'WTINT2YR', 'BPXSY1']].head()
# Out:
#      ALQ130  WTINT2YR    BPXSY1
# 0  0.000000  0.566227  0.298701
# 1  0.005010  0.083168  0.415584
# 2  0.002917  0.030947  0.363636
# 3  0.000000  0.426342  0.324675
# 4  0.000000  0.053833  0.116883

# %%
mydata[['ALQ130', 'WTINT2YR', 'BPXSY1']].describe()
# Out:
#             ALQ130     WTINT2YR       BPXSY1
# count  5735.000000  5735.000000  5735.000000
# mean      0.002917     0.153142     0.279770
# std       0.026412     0.169723     0.116458
# min       0.000000     0.000000     0.000000
# 25%       0.001002     0.051803     0.207792
# 50%       0.002917     0.084596     0.272727
# 75%       0.002917     0.164305     0.337662
# max       1.000000     1.000000     1.000000
